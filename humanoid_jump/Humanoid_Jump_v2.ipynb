# %%
# @title 1. Environment Setup & Installation

# !apt-get install -y \
    libgl1-mesa-dev \
    libgl1-mesa-glx \
    libglew-dev \
    libosmesa6-dev \
    software-properties-common \
    patchelf \
    ffmpeg \
    xvfb

# !pip install gymnasium[mujoco] stable-baselines3 shimmy imageio[ffmpeg] pyvirtualdisplay
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# software-properties-common is already the newest version (0.99.22.9).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   libegl-dev libgl-dev libgles-dev libgles1 libglew2.2 libglu1-mesa
#   libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libopengl-dev
#   libosmesa6
# Suggested packages:
#   glew-utils
# The following NEW packages will be installed:
#   libegl-dev libgl-dev libgl1-mesa-dev libgles-dev libgles1 libglew-dev
#   libglew2.2 libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev
#   libglx-dev libopengl-dev libosmesa6 libosmesa6-dev patchelf
# 0 upgraded, 16 newly installed, 0 to remove and 2 not upgraded.
# Need to get 4,275 kB of archives.
# After this operation, 20.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [6,848 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew2.2 amd64 2.2.0-4 [196 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew-dev amd64 2.2.0-4 [287 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 patchelf amd64 0.14.3-1 [72.1 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libosmesa6 amd64 23.2.1-1ubuntu3.1~22.04.3 [3,115 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libosmesa6-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [8,984 B]
# Fetched 4,275 kB in 2s (1,783 kB/s)
# Selecting previously unselected package libglx-dev:amd64.
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../00-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../01-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../02-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../03-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../04-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../05-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../06-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../07-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../08-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libglew2.2:amd64.
# Preparing to unpack .../09-libglew2.2_2.2.0-4_amd64.deb ...
# Unpacking libglew2.2:amd64 (2.2.0-4) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../10-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../11-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglew-dev:amd64.
# Preparing to unpack .../12-libglew-dev_2.2.0-4_amd64.deb ...
# Unpacking libglew-dev:amd64 (2.2.0-4) ...
# Selecting previously unselected package patchelf.
# Preparing to unpack .../13-patchelf_0.14.3-1_amd64.deb ...
# Unpacking patchelf (0.14.3-1) ...
# Selecting previously unselected package libosmesa6:amd64.
# Preparing to unpack .../14-libosmesa6_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libosmesa6:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libosmesa6-dev:amd64.
# Preparing to unpack .../15-libosmesa6-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libglew2.2:amd64 (2.2.0-4) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up patchelf (0.14.3-1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libosmesa6:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libglew-dev:amd64 (2.2.0-4) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: gymnasium[mujoco] in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: imageio[ffmpeg] in /usr/local/lib/python3.12/dist-packages (2.37.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (0.0.4)
# Collecting mujoco>=2.1.5 (from gymnasium[mujoco])
#   Downloading mujoco-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (26.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cpu)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio[ffmpeg]) (11.3.0)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (from imageio[ffmpeg]) (0.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from imageio[ffmpeg]) (5.9.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.13.0)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (3.1.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 6.4 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Downloading mujoco-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 47.3 MB/s eta 0:00:00
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 22.1 MB/s eta 0:00:00
# Installing collected packages: pyvirtualdisplay, glfw, shimmy, stable-baselines3, mujoco
# Successfully installed glfw-2.10.0 mujoco-3.4.0 pyvirtualdisplay-3.0 shimmy-2.0.0 stable-baselines3-2.7.1

# %%
#   ✗ NO alive bonus — zero reward for standing still
#   ✗ NO phase state machine — too hard to discover in sequence
#   ✓ Upward velocity as PRIMARY signal (always on, not gated)
#   ✓ LOW flight threshold (z > 0.8) — micro-hops get rewarded
#   ✓ Flight reward scales with height — incentivizes jumping HIGHER
#   ✓ Smooth gradient: standing (≈0.1) → extending (≈0.6) → hop (≈3) → jump (≈6)
# =============================================================================

import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize
from stable_baselines3.common.callbacks import BaseCallback
import torch.nn as nn
import torch
import os

# ── Geom IDs (Humanoid-v5) ──────────────────────────────────────────────────
FLOOR_GEOM_ID      = 0
RIGHT_FOOT_GEOM_ID = 8
LEFT_FOOT_GEOM_ID  = 11
FOOT_GEOM_IDS      = {RIGHT_FOOT_GEOM_ID, LEFT_FOOT_GEOM_ID}

STANDING_Z = 1.4


# =============================================================================
# Jump Wrapper v2c — Simplified
# =============================================================================
class JumpRewardWrapper(gym.Wrapper):
    """
    Simplified jump reward. No phase machine, no alive bonus.

    Reward gradient:
        standing still    →  ~0.08 / step  (just the height baseline)
        extending legs    →  ~0.6  / step  (upward velocity kicks in)
        micro-hop         →  ~3.0  / step  (flight bonus at any height)
        real jump         →  ~6.0  / step  (flight + height scaling)
    """

    def __init__(self, env, max_episode_steps=300):
        super().__init__(env)
        self.max_episode_steps = max_episode_steps
        self._reset_tracking()

    def _reset_tracking(self):
        self.step_count = 0
        self.max_z = -np.inf
        self.total_flight_steps = 0       # steps with feet off ground + z > 0.8
        self.max_flight_z = -np.inf
        self.entered_flight = False

        # Action history for jerk penalty
        self.action_hist = [
            np.zeros(self.action_space.shape),
            np.zeros(self.action_space.shape),
        ]

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self._reset_tracking()
        return obs, info

    # ── Contact helpers ──────────────────────────────────────────────────
    def _get_floor_contacts(self):
        d = self.unwrapped.data
        touching_floor = set()
        for i in range(d.ncon):
            c = d.contact[i]
            pair = {c.geom1, c.geom2}
            if FLOOR_GEOM_ID in pair:
                other = (pair - {FLOOR_GEOM_ID}).pop()
                touching_floor.add(other)
        return touching_floor

    def _feet_on_ground(self, floor_contacts):
        return len(FOOT_GEOM_IDS & floor_contacts)

    def _non_foot_on_ground(self, floor_contacts):
        return len(floor_contacts - FOOT_GEOM_IDS) > 0

    # ── Main step ────────────────────────────────────────────────────────
    def step(self, action):
        obs, _, terminated, truncated, info = self.env.step(action)
        self.step_count += 1

        # ── Gather state ──
        x, y, z = self.unwrapped.data.qpos[0:3]
        vx, vy, vz = self.unwrapped.data.qvel[0:3]
        floor_contacts = self._get_floor_contacts()
        n_feet = self._feet_on_ground(floor_contacts)
        body_fell = self._non_foot_on_ground(floor_contacts)
        airborne = (n_feet == 0) and (not body_fell)

        self.max_z = max(self.max_z, z)

        # ══════════════════════════════════════════════════════════════════
        # REWARD — smooth gradient from standing → jumping
        # ══════════════════════════════════════════════════════════════════
        reward = 0.0

        # ▸ 1. UPWARD VELOCITY — primary gradient signal
        #   Always on, not gated by phase or position.
        #   Rewards any upward movement: leg extension, push-off, etc.
        #   Capped to prevent outliers from messing up VecNormalize.
        reward += 0.5 * np.clip(vz, 0.0, 5.0)

        # ▸ 2. FLIGHT BONUS — the big reward for actual airborne time
        #   LOW threshold: z > 0.8 (just "not collapsed on the floor")
        #   so even tiny hops where COM dips to z≈1.2 during push-off
        #   get rewarded. Then scales heavily with height.
        if airborne and z > 0.8:
            reward += 2.0                                     # base: "you're airborne!"
            reward += 5.0 * max(0.0, z - STANDING_Z)         # bonus for height
            reward += 1.0 * np.clip(vz, 0.0, 5.0)           # going up while flying

            # Track for metrics
            self.total_flight_steps += 1
            self.max_flight_z = max(self.max_flight_z, z)
            self.entered_flight = True

        # ▸ 3. HEIGHT BASELINE — tiny always-on signal
        #   Provides gradient toward "be tall / extend legs."
        #   Standing at z=1.4 gives 0.08, which is almost nothing.
        reward += 0.2 * max(0.0, z - 1.0)

        # ▸ 4. NO ALIVE BONUS — standing still ≈ 0.08 reward (just height)

        # ▸ 5. POSTURE — penalize body parts (not feet) touching floor
        if body_fell:
            reward -= 3.0

        # ▸ 6. STAY CENTERED
        drift = np.sqrt(x**2 + y**2)
        reward -= 0.1 * drift

        # ▸ 7. JERK PENALTY — catches vibration, allows explosive moves
        jerk = action - 2.0 * self.action_hist[-1] + self.action_hist[-2]
        reward -= 0.02 * np.sum(np.square(jerk))

        # ▸ 8. CONTROL COST
        reward -= 0.005 * np.sum(np.square(action))

        # ▸ 9. EPISODE END — info for metrics (no terminal bonus)
        is_done = terminated or truncated or (self.step_count >= self.max_episode_steps)
        if is_done:
            if self.entered_flight:
                info["jump_height"] = self.max_flight_z - STANDING_Z
                info["flight_steps"] = self.total_flight_steps
            if not terminated and not truncated:
                truncated = True

        # ── TERMINATION ──
        if z < 0.3:
            terminated = True
            reward -= 3.0
        if drift > 1.0:
            terminated = True
            reward -= 2.0

        # Update action history
        self.action_hist[-2] = self.action_hist[-1].copy()
        self.action_hist[-1] = action.copy()

        return obs, reward, terminated, truncated, info


# =============================================================================
# Callbacks
# =============================================================================
class JumpMetricsCallback(BaseCallback):
    def __init__(self, print_every=10_000, verbose=0):
        super().__init__(verbose)
        self.print_every = print_every
        self.jump_heights = []
        self.flight_steps_list = []
        self.ep_count = 0
        self.flight_ep_count = 0

    def _on_step(self) -> bool:
        for info in self.locals.get("infos", []):
            self.ep_count += 1
            if "jump_height" in info:
                self.jump_heights.append(info["jump_height"])
                self.flight_steps_list.append(info["flight_steps"])
                self.flight_ep_count += 1

        if self.num_timesteps % self.print_every == 0:
            if self.jump_heights:
                recent_h = self.jump_heights[-50:]
                recent_f = self.flight_steps_list[-50:]
                frac = self.flight_ep_count / max(self.ep_count, 1)
                print(
                    f"  [Jump] step={self.num_timesteps:,}  "
                    f"flight_rate={frac:.1%}  "
                    f"avg_h={np.mean(recent_h):.3f}m  "
                    f"max_h={np.max(recent_h):.3f}m  "
                    f"avg_flight={np.mean(recent_f):.1f}steps"
                )
                self.logger.record("jump/avg_height", np.mean(recent_h))
                self.logger.record("jump/max_height", np.max(recent_h))
                self.logger.record("jump/flight_rate", frac)
            else:
                print(
                    f"  [Jump] step={self.num_timesteps:,}  "
                    f"NO FLIGHTS YET ({self.ep_count} episodes)"
                )
        return True


class DiagnosticCallback(BaseCallback):
    def __init__(self, print_every=50_000, verbose=0):
        super().__init__(verbose)
        self.print_every = print_every

    def _on_step(self) -> bool:
        if self.num_timesteps % self.print_every == 0:
            logs = self.logger.name_to_value
            kl = logs.get("train/approx_kl", "?")
            clip = logs.get("train/clip_fraction", "?")
            ev = logs.get("train/explained_variance", "?")
            std = logs.get("train/std", "?")
            print(
                f"  [Health] step={self.num_timesteps:,}  "
                f"kl={kl}  clip={clip}  expl_var={ev}  std={std}"
            )
        return True


# =============================================================================
# Environment factory
# =============================================================================
def make_env(max_episode_steps=300, seed=0):
    def _init():
        env = gym.make("Humanoid-v5", render_mode=None)
        env = JumpRewardWrapper(env, max_episode_steps=max_episode_steps)
        env.reset(seed=seed)
        return env
    return _init


# =============================================================================
# Training
# =============================================================================
def run_training(
    n_envs: int = 8,
    total_timesteps: int = 5_000_000,
    max_episode_steps: int = 300,
):
    print(f"=== Humanoid Jump Training v2c ===")
    print(f"  Parallel envs:     {n_envs}")
    print(f"  Total timesteps:   {total_timesteps:,}")
    print(f"  Max episode steps: {max_episode_steps}")
    print(f"  Device:            {'cuda' if torch.cuda.is_available() else 'cpu'}")
    print(f"  Key changes:       no alive bonus, no phase machine,")
    print(f"                     low flight threshold, velocity gradient")
    print()

    # ── Environments ──
    venv = SubprocVecEnv([
        make_env(max_episode_steps=max_episode_steps, seed=i)
        for i in range(n_envs)
    ])
    env = VecNormalize(
        venv,
        norm_obs=True,
        norm_reward=True,
        clip_obs=10.0,
        clip_reward=10.0,
        gamma=0.99,
    )

    # ── PPO ──
    policy_kwargs = dict(
        activation_fn=nn.ELU,
        net_arch=dict(pi=[256, 256], vf=[256, 256]),
    )

    model = PPO(
        "MlpPolicy",
        env,
        verbose=1,
        learning_rate=3e-4,
        n_steps=2048,
        batch_size=1024,
        n_epochs=5,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.01,
        vf_coef=0.5,
        max_grad_norm=0.5,
        target_kl=0.05,
        device="cuda" if torch.cuda.is_available() else "cpu",
        policy_kwargs=policy_kwargs,
        tensorboard_log="./jump_tb_logs/",
    )

    # ── Train ──
    print("--- Starting training ---\n")
    model.learn(
        total_timesteps=total_timesteps,
        callback=[
            JumpMetricsCallback(print_every=20_000, verbose=1),
            DiagnosticCallback(print_every=100_000, verbose=1),
        ],
    )
    print("\n--- Training complete ---")

    model.save("humanoid_jumper_v2")
    env.save("humanoid_jumper_v2_vecnorm.pkl")
    env.close()
    print("Saved: humanoid_jumper_v2.zip + humanoid_jumper_v2_vecnorm.pkl")

    return model


# =============================================================================
# Run
# =============================================================================
model = run_training()
# Out:
# === Humanoid Jump Training v2c ===
#   Parallel envs:     8
#   Total timesteps:   5,000,000
#   Max episode steps: 300
#   Device:            cpu
#   Key changes:       no alive bonus, no phase machine,
#                      low flight threshold, velocity gradient
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Using cpu device
# --- Starting training ---
#
# Logging to ./jump_tb_logs/PPO_1
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Streaming output truncated to the last 5000 lines.
#   [Jump] step=1,520,000  flight_rate=1.5%  avg_h=-0.000m  max_h=0.034m  avg_flight=68.0steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | -0.000384   |
# |    flight_rate          | 0.0154      |
# |    max_height           | 0.0339      |
# | time/                   |             |
# |    fps                  | 911         |
# |    iterations           | 93          |
# |    time_elapsed         | 1672        |
# |    total_timesteps      | 1523712     |
# | train/                  |             |
# |    approx_kl            | 0.047659848 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.4       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.3        |
# |    n_updates            | 458         |
# |    policy_gradient_loss | -0.0439     |
# |    std                  | 1.22        |
# |    value_loss           | 0.105       |
# -----------------------------------------
#   [Jump] step=1,540,000  flight_rate=1.5%  avg_h=0.004m  max_h=0.070m  avg_flight=78.0steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.00369    |
# |    flight_rate          | 0.0153     |
# |    max_height           | 0.0698     |
# | time/                   |            |
# |    fps                  | 911        |
# |    iterations           | 94         |
# |    time_elapsed         | 1688       |
# |    total_timesteps      | 1540096    |
# | train/                  |            |
# |    approx_kl            | 0.04527534 |
# |    clip_fraction        | 0.38       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.4      |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.3       |
# |    n_updates            | 463        |
# |    policy_gradient_loss | -0.0438    |
# |    std                  | 1.22       |
# |    value_loss           | 0.098      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 95          |
# |    time_elapsed         | 1705        |
# |    total_timesteps      | 1556480     |
# | train/                  |             |
# |    approx_kl            | 0.043918155 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.5       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.315      |
# |    n_updates            | 468         |
# |    policy_gradient_loss | -0.0436     |
# |    std                  | 1.22        |
# |    value_loss           | 0.092       |
# -----------------------------------------
#   [Jump] step=1,560,000  flight_rate=1.5%  avg_h=0.002m  max_h=0.066m  avg_flight=72.0steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00171     |
# |    flight_rate          | 0.0152      |
# |    max_height           | 0.0661      |
# | time/                   |             |
# |    fps                  | 913         |
# |    iterations           | 96          |
# |    time_elapsed         | 1722        |
# |    total_timesteps      | 1572864     |
# | train/                  |             |
# |    approx_kl            | 0.042199567 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.5       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.306      |
# |    n_updates            | 473         |
# |    policy_gradient_loss | -0.0436     |
# |    std                  | 1.23        |
# |    value_loss           | 0.102       |
# -----------------------------------------
#   [Jump] step=1,580,000  flight_rate=1.5%  avg_h=0.000m  max_h=0.055m  avg_flight=74.6steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.000222    |
# |    flight_rate          | 0.0151      |
# |    max_height           | 0.0553      |
# | time/                   |             |
# |    fps                  | 913         |
# |    iterations           | 97          |
# |    time_elapsed         | 1738        |
# |    total_timesteps      | 1589248     |
# | train/                  |             |
# |    approx_kl            | 0.046797004 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.6       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.306      |
# |    n_updates            | 478         |
# |    policy_gradient_loss | -0.0428     |
# |    std                  | 1.23        |
# |    value_loss           | 0.0982      |
# -----------------------------------------
#   [Jump] step=1,600,000  flight_rate=1.5%  avg_h=0.001m  max_h=0.032m  avg_flight=78.8steps
#   [Health] step=1,600,000  kl=0.04954242706298828  clip=0.391748046875  expl_var=0.9110940098762512  std=1.2334643602371216
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00069     |
# |    flight_rate          | 0.0149      |
# |    max_height           | 0.032       |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 98          |
# |    time_elapsed         | 1755        |
# |    total_timesteps      | 1605632     |
# | train/                  |             |
# |    approx_kl            | 0.049542427 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.6       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.304      |
# |    n_updates            | 483         |
# |    policy_gradient_loss | -0.0436     |
# |    std                  | 1.23        |
# |    value_loss           | 0.0958      |
# -----------------------------------------
#   [Jump] step=1,620,000  flight_rate=1.5%  avg_h=-0.001m  max_h=0.012m  avg_flight=72.2steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | -0.00137    |
# |    flight_rate          | 0.0148      |
# |    max_height           | 0.0125      |
# | time/                   |             |
# |    fps                  | 915         |
# |    iterations           | 99          |
# |    time_elapsed         | 1772        |
# |    total_timesteps      | 1622016     |
# | train/                  |             |
# |    approx_kl            | 0.046198495 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.7       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.306      |
# |    n_updates            | 488         |
# |    policy_gradient_loss | -0.0442     |
# |    std                  | 1.24        |
# |    value_loss           | 0.0966      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 915         |
# |    iterations           | 100         |
# |    time_elapsed         | 1788        |
# |    total_timesteps      | 1638400     |
# | train/                  |             |
# |    approx_kl            | 0.045656223 |
# |    clip_fraction        | 0.378       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.7       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.312      |
# |    n_updates            | 493         |
# |    policy_gradient_loss | -0.0443     |
# |    std                  | 1.24        |
# |    value_loss           | 0.0989      |
# -----------------------------------------
#   [Jump] step=1,640,000  flight_rate=1.5%  avg_h=0.001m  max_h=0.042m  avg_flight=72.3steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00122     |
# |    flight_rate          | 0.0147      |
# |    max_height           | 0.0415      |
# | time/                   |             |
# |    fps                  | 916         |
# |    iterations           | 101         |
# |    time_elapsed         | 1805        |
# |    total_timesteps      | 1654784     |
# | train/                  |             |
# |    approx_kl            | 0.045911565 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.8       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.309      |
# |    n_updates            | 498         |
# |    policy_gradient_loss | -0.0427     |
# |    std                  | 1.24        |
# |    value_loss           | 0.101       |
# -----------------------------------------
#   [Jump] step=1,660,000  flight_rate=1.5%  avg_h=0.002m  max_h=0.064m  avg_flight=73.0steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00174     |
# |    flight_rate          | 0.0146      |
# |    max_height           | 0.0636      |
# | time/                   |             |
# |    fps                  | 917         |
# |    iterations           | 102         |
# |    time_elapsed         | 1821        |
# |    total_timesteps      | 1671168     |
# | train/                  |             |
# |    approx_kl            | 0.046226095 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.8       |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.31       |
# |    n_updates            | 503         |
# |    policy_gradient_loss | -0.0414     |
# |    std                  | 1.25        |
# |    value_loss           | 0.102       |
# -----------------------------------------
#   [Jump] step=1,680,000  flight_rate=1.4%  avg_h=-0.001m  max_h=0.016m  avg_flight=74.6steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | -0.000689  |
# |    flight_rate          | 0.0145     |
# |    max_height           | 0.0156     |
# | time/                   |            |
# |    fps                  | 918        |
# |    iterations           | 103        |
# |    time_elapsed         | 1838       |
# |    total_timesteps      | 1687552    |
# | train/                  |            |
# |    approx_kl            | 0.04382194 |
# |    clip_fraction        | 0.379      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.8      |
# |    explained_variance   | 0.911      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.319     |
# |    n_updates            | 508        |
# |    policy_gradient_loss | -0.042     |
# |    std                  | 1.25       |
# |    value_loss           | 0.0958     |
# ----------------------------------------
#   [Jump] step=1,700,000  flight_rate=1.4%  avg_h=-0.000m  max_h=0.042m  avg_flight=82.6steps
#   [Health] step=1,700,000  kl=0.04441449046134949  clip=0.37652587890625  expl_var=0.9108112454414368  std=1.2531561851501465
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | -3.17e-05  |
# |    flight_rate          | 0.0144     |
# |    max_height           | 0.042      |
# | time/                   |            |
# |    fps                  | 918        |
# |    iterations           | 104        |
# |    time_elapsed         | 1854       |
# |    total_timesteps      | 1703936    |
# | train/                  |            |
# |    approx_kl            | 0.04441449 |
# |    clip_fraction        | 0.377      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.9      |
# |    explained_variance   | 0.911      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.319     |
# |    n_updates            | 513        |
# |    policy_gradient_loss | -0.0421    |
# |    std                  | 1.25       |
# |    value_loss           | 0.0951     |
# ----------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.20
#   [Jump] step=1,720,000  flight_rate=1.4%  avg_h=-0.001m  max_h=0.008m  avg_flight=74.2steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | -0.000694   |
# |    flight_rate          | 0.0143      |
# |    max_height           | 0.00821     |
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 105         |
# |    time_elapsed         | 1871        |
# |    total_timesteps      | 1720320     |
# | train/                  |             |
# |    approx_kl            | 0.050938077 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.305      |
# |    n_updates            | 517         |
# |    policy_gradient_loss | -0.035      |
# |    std                  | 1.25        |
# |    value_loss           | 0.098       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 106         |
# |    time_elapsed         | 1887        |
# |    total_timesteps      | 1736704     |
# | train/                  |             |
# |    approx_kl            | 0.045283973 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.316      |
# |    n_updates            | 522         |
# |    policy_gradient_loss | -0.0426     |
# |    std                  | 1.26        |
# |    value_loss           | 0.101       |
# -----------------------------------------
#   [Jump] step=1,740,000  flight_rate=1.4%  avg_h=-0.001m  max_h=0.027m  avg_flight=73.0steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | -0.000882   |
# |    flight_rate          | 0.0142      |
# |    max_height           | 0.0271      |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 107         |
# |    time_elapsed         | 1903        |
# |    total_timesteps      | 1753088     |
# | train/                  |             |
# |    approx_kl            | 0.050077345 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.315      |
# |    n_updates            | 527         |
# |    policy_gradient_loss | -0.0444     |
# |    std                  | 1.26        |
# |    value_loss           | 0.0833      |
# -----------------------------------------
#   [Jump] step=1,760,000  flight_rate=1.4%  avg_h=-0.001m  max_h=0.024m  avg_flight=79.3steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | -0.00051    |
# |    flight_rate          | 0.0141      |
# |    max_height           | 0.0237      |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 108         |
# |    time_elapsed         | 1920        |
# |    total_timesteps      | 1769472     |
# | train/                  |             |
# |    approx_kl            | 0.047116205 |
# |    clip_fraction        | 0.388       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.315      |
# |    n_updates            | 532         |
# |    policy_gradient_loss | -0.0418     |
# |    std                  | 1.26        |
# |    value_loss           | 0.0896      |
# -----------------------------------------
#   [Jump] step=1,780,000  flight_rate=1.4%  avg_h=-0.001m  max_h=0.017m  avg_flight=72.9steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | -0.000553   |
# |    flight_rate          | 0.014       |
# |    max_height           | 0.0174      |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 109         |
# |    time_elapsed         | 1937        |
# |    total_timesteps      | 1785856     |
# | train/                  |             |
# |    approx_kl            | 0.046046518 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.319      |
# |    n_updates            | 537         |
# |    policy_gradient_loss | -0.043      |
# |    std                  | 1.26        |
# |    value_loss           | 0.0852      |
# -----------------------------------------
#   [Jump] step=1,800,000  flight_rate=1.4%  avg_h=0.000m  max_h=0.055m  avg_flight=78.3steps
#   [Health] step=1,800,000  kl=0.04582567140460014  clip=0.3820068359375  expl_var=0.9050850868225098  std=1.2677751779556274
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.000223   |
# |    flight_rate          | 0.0138     |
# |    max_height           | 0.0546     |
# | time/                   |            |
# |    fps                  | 922        |
# |    iterations           | 110        |
# |    time_elapsed         | 1954       |
# |    total_timesteps      | 1802240    |
# | train/                  |            |
# |    approx_kl            | 0.04582567 |
# |    clip_fraction        | 0.382      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.1      |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.323     |
# |    n_updates            | 542        |
# |    policy_gradient_loss | -0.0419    |
# |    std                  | 1.27       |
# |    value_loss           | 0.0967     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 922         |
# |    iterations           | 111         |
# |    time_elapsed         | 1970        |
# |    total_timesteps      | 1818624     |
# | train/                  |             |
# |    approx_kl            | 0.048205137 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.1       |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.314      |
# |    n_updates            | 547         |
# |    policy_gradient_loss | -0.044      |
# |    std                  | 1.27        |
# |    value_loss           | 0.101       |
# -----------------------------------------
#   [Jump] step=1,820,000  flight_rate=1.4%  avg_h=0.001m  max_h=0.029m  avg_flight=82.9steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.000787    |
# |    flight_rate          | 0.0137      |
# |    max_height           | 0.0287      |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 112         |
# |    time_elapsed         | 1987        |
# |    total_timesteps      | 1835008     |
# | train/                  |             |
# |    approx_kl            | 0.044696208 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.311      |
# |    n_updates            | 552         |
# |    policy_gradient_loss | -0.0421     |
# |    std                  | 1.28        |
# |    value_loss           | 0.0964      |
# -----------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.16
#   [Jump] step=1,840,000  flight_rate=1.4%  avg_h=0.001m  max_h=0.056m  avg_flight=79.5steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.00138    |
# |    flight_rate          | 0.0136     |
# |    max_height           | 0.0559     |
# | time/                   |            |
# |    fps                  | 924        |
# |    iterations           | 113        |
# |    time_elapsed         | 2003       |
# |    total_timesteps      | 1851392    |
# | train/                  |            |
# |    approx_kl            | 0.06927465 |
# |    clip_fraction        | 0.375      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.2      |
# |    explained_variance   | 0.904      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.33      |
# |    n_updates            | 557        |
# |    policy_gradient_loss | -0.037     |
# |    std                  | 1.28       |
# |    value_loss           | 0.0941     |
# ----------------------------------------
#   [Jump] step=1,860,000  flight_rate=1.4%  avg_h=-0.001m  max_h=0.041m  avg_flight=76.8steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | -0.000661   |
# |    flight_rate          | 0.0135      |
# |    max_height           | 0.0412      |
# | time/                   |             |
# |    fps                  | 924         |
# |    iterations           | 114         |
# |    time_elapsed         | 2020        |
# |    total_timesteps      | 1867776     |
# | train/                  |             |
# |    approx_kl            | 0.045910057 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.3       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.323      |
# |    n_updates            | 562         |
# |    policy_gradient_loss | -0.0425     |
# |    std                  | 1.28        |
# |    value_loss           | 0.0909      |
# -----------------------------------------
#   [Jump] step=1,880,000  flight_rate=1.3%  avg_h=0.002m  max_h=0.123m  avg_flight=85.9steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00161     |
# |    flight_rate          | 0.0134      |
# |    max_height           | 0.123       |
# | time/                   |             |
# |    fps                  | 924         |
# |    iterations           | 115         |
# |    time_elapsed         | 2037        |
# |    total_timesteps      | 1884160     |
# | train/                  |             |
# |    approx_kl            | 0.049674757 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.3       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.316      |
# |    n_updates            | 567         |
# |    policy_gradient_loss | -0.043      |
# |    std                  | 1.29        |
# |    value_loss           | 0.104       |
# -----------------------------------------
#   [Jump] step=1,900,000  flight_rate=1.3%  avg_h=-0.000m  max_h=0.015m  avg_flight=86.1steps
#   [Health] step=1,900,000  kl=0.04540121182799339  clip=0.3880126953125  expl_var=0.8977510333061218  std=1.291845440864563
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | -0.000238  |
# |    flight_rate          | 0.0133     |
# |    max_height           | 0.0153     |
# | time/                   |            |
# |    fps                  | 925        |
# |    iterations           | 116        |
# |    time_elapsed         | 2054       |
# |    total_timesteps      | 1900544    |
# | train/                  |            |
# |    approx_kl            | 0.04540121 |
# |    clip_fraction        | 0.388      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.4      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.313     |
# |    n_updates            | 572        |
# |    policy_gradient_loss | -0.0413    |
# |    std                  | 1.29       |
# |    value_loss           | 0.107      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 925         |
# |    iterations           | 117         |
# |    time_elapsed         | 2070        |
# |    total_timesteps      | 1916928     |
# | train/                  |             |
# |    approx_kl            | 0.044705845 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.328      |
# |    n_updates            | 577         |
# |    policy_gradient_loss | -0.044      |
# |    std                  | 1.29        |
# |    value_loss           | 0.0947      |
# -----------------------------------------
#   [Jump] step=1,920,000  flight_rate=1.3%  avg_h=0.001m  max_h=0.030m  avg_flight=78.2steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00125     |
# |    flight_rate          | 0.0133      |
# |    max_height           | 0.0297      |
# | time/                   |             |
# |    fps                  | 925         |
# |    iterations           | 118         |
# |    time_elapsed         | 2087        |
# |    total_timesteps      | 1933312     |
# | train/                  |             |
# |    approx_kl            | 0.046807677 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.322      |
# |    n_updates            | 582         |
# |    policy_gradient_loss | -0.044      |
# |    std                  | 1.3         |
# |    value_loss           | 0.0913      |
# -----------------------------------------
#   [Jump] step=1,940,000  flight_rate=1.3%  avg_h=-0.001m  max_h=0.042m  avg_flight=84.2steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | -0.000818   |
# |    flight_rate          | 0.0131      |
# |    max_height           | 0.0421      |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 119         |
# |    time_elapsed         | 2104        |
# |    total_timesteps      | 1949696     |
# | train/                  |             |
# |    approx_kl            | 0.043127432 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.313      |
# |    n_updates            | 587         |
# |    policy_gradient_loss | -0.0406     |
# |    std                  | 1.3         |
# |    value_loss           | 0.103       |
# -----------------------------------------
#   [Jump] step=1,960,000  flight_rate=1.3%  avg_h=0.001m  max_h=0.030m  avg_flight=81.8steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.000527    |
# |    flight_rate          | 0.0131      |
# |    max_height           | 0.0303      |
# | time/                   |             |
# |    fps                  | 927         |
# |    iterations           | 120         |
# |    time_elapsed         | 2120        |
# |    total_timesteps      | 1966080     |
# | train/                  |             |
# |    approx_kl            | 0.045072075 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.6       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.325      |
# |    n_updates            | 592         |
# |    policy_gradient_loss | -0.0425     |
# |    std                  | 1.31        |
# |    value_loss           | 0.0892      |
# -----------------------------------------
#   [Jump] step=1,980,000  flight_rate=1.3%  avg_h=0.001m  max_h=0.029m  avg_flight=84.9steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00116     |
# |    flight_rate          | 0.013       |
# |    max_height           | 0.0287      |
# | time/                   |             |
# |    fps                  | 927         |
# |    iterations           | 121         |
# |    time_elapsed         | 2137        |
# |    total_timesteps      | 1982464     |
# | train/                  |             |
# |    approx_kl            | 0.044702098 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.6       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.321      |
# |    n_updates            | 597         |
# |    policy_gradient_loss | -0.0439     |
# |    std                  | 1.31        |
# |    value_loss           | 0.0931      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 927         |
# |    iterations           | 122         |
# |    time_elapsed         | 2154        |
# |    total_timesteps      | 1998848     |
# | train/                  |             |
# |    approx_kl            | 0.045897115 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.6       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.318      |
# |    n_updates            | 602         |
# |    policy_gradient_loss | -0.0408     |
# |    std                  | 1.31        |
# |    value_loss           | 0.0979      |
# -----------------------------------------
#   [Jump] step=2,000,000  flight_rate=1.3%  avg_h=0.001m  max_h=0.051m  avg_flight=89.3steps
#   [Health] step=2,000,000  kl=0.04525022953748703  clip=0.38778076171875  expl_var=0.9147749543190002  std=1.3163472414016724
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.00149    |
# |    flight_rate          | 0.0129     |
# |    max_height           | 0.0512     |
# | time/                   |            |
# |    fps                  | 928        |
# |    iterations           | 123        |
# |    time_elapsed         | 2171       |
# |    total_timesteps      | 2015232    |
# | train/                  |            |
# |    approx_kl            | 0.04525023 |
# |    clip_fraction        | 0.388      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.7      |
# |    explained_variance   | 0.915      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.318     |
# |    n_updates            | 607        |
# |    policy_gradient_loss | -0.0406    |
# |    std                  | 1.32       |
# |    value_loss           | 0.0846     |
# ----------------------------------------
#   [Jump] step=2,020,000  flight_rate=1.3%  avg_h=0.001m  max_h=0.034m  avg_flight=94.2steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.000856   |
# |    flight_rate          | 0.0128     |
# |    max_height           | 0.0342     |
# | time/                   |            |
# |    fps                  | 928        |
# |    iterations           | 124        |
# |    time_elapsed         | 2187       |
# |    total_timesteps      | 2031616    |
# | train/                  |            |
# |    approx_kl            | 0.04468941 |
# |    clip_fraction        | 0.385      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.7      |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.322     |
# |    n_updates            | 612        |
# |    policy_gradient_loss | -0.0428    |
# |    std                  | 1.32       |
# |    value_loss           | 0.0878     |
# ----------------------------------------
#   [Jump] step=2,040,000  flight_rate=1.3%  avg_h=0.001m  max_h=0.035m  avg_flight=92.2steps
# --------------------------------------
# | jump/                   |          |
# |    avg_height           | 0.00134  |
# |    flight_rate          | 0.0127   |
# |    max_height           | 0.0348   |
# | time/                   |          |
# |    fps                  | 929      |
# |    iterations           | 125      |
# |    time_elapsed         | 2203     |
# |    total_timesteps      | 2048000  |
# | train/                  |          |
# |    approx_kl            | 0.040983 |
# |    clip_fraction        | 0.371    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -28.8    |
# |    explained_variance   | 0.896    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.321   |
# |    n_updates            | 617      |
# |    policy_gradient_loss | -0.0397  |
# |    std                  | 1.32     |
# |    value_loss           | 0.105    |
# --------------------------------------
#   [Jump] step=2,060,000  flight_rate=1.3%  avg_h=0.001m  max_h=0.034m  avg_flight=91.4steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00108     |
# |    flight_rate          | 0.0126      |
# |    max_height           | 0.0344      |
# | time/                   |             |
# |    fps                  | 929         |
# |    iterations           | 126         |
# |    time_elapsed         | 2219        |
# |    total_timesteps      | 2064384     |
# | train/                  |             |
# |    approx_kl            | 0.045863297 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.8       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.319      |
# |    n_updates            | 622         |
# |    policy_gradient_loss | -0.0421     |
# |    std                  | 1.33        |
# |    value_loss           | 0.101       |
# -----------------------------------------
#   [Jump] step=2,080,000  flight_rate=1.2%  avg_h=0.003m  max_h=0.043m  avg_flight=95.2steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.00268    |
# |    flight_rate          | 0.0125     |
# |    max_height           | 0.0431     |
# | time/                   |            |
# |    fps                  | 930        |
# |    iterations           | 127        |
# |    time_elapsed         | 2236       |
# |    total_timesteps      | 2080768    |
# | train/                  |            |
# |    approx_kl            | 0.04395112 |
# |    clip_fraction        | 0.386      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.9      |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.314     |
# |    n_updates            | 627        |
# |    policy_gradient_loss | -0.0426    |
# |    std                  | 1.33       |
# |    value_loss           | 0.104      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 931        |
# |    iterations           | 128        |
# |    time_elapsed         | 2252       |
# |    total_timesteps      | 2097152    |
# | train/                  |            |
# |    approx_kl            | 0.04343616 |
# |    clip_fraction        | 0.381      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.9      |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.324     |
# |    n_updates            | 632        |
# |    policy_gradient_loss | -0.0414    |
# |    std                  | 1.34       |
# |    value_loss           | 0.0966     |
# ----------------------------------------
#   [Jump] step=2,100,000  flight_rate=1.2%  avg_h=0.002m  max_h=0.032m  avg_flight=98.0steps
#   [Health] step=2,100,000  kl=0.044427432119846344  clip=0.3766845703125  expl_var=0.90146404504776  std=1.3403698205947876
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00227     |
# |    flight_rate          | 0.0124      |
# |    max_height           | 0.0316      |
# | time/                   |             |
# |    fps                  | 931         |
# |    iterations           | 129         |
# |    time_elapsed         | 2268        |
# |    total_timesteps      | 2113536     |
# | train/                  |             |
# |    approx_kl            | 0.044427432 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29         |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.331      |
# |    n_updates            | 637         |
# |    policy_gradient_loss | -0.0449     |
# |    std                  | 1.34        |
# |    value_loss           | 0.0979      |
# -----------------------------------------
#   [Jump] step=2,120,000  flight_rate=1.2%  avg_h=0.003m  max_h=0.053m  avg_flight=97.8steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.003      |
# |    flight_rate          | 0.0123     |
# |    max_height           | 0.0532     |
# | time/                   |            |
# |    fps                  | 931        |
# |    iterations           | 130        |
# |    time_elapsed         | 2285       |
# |    total_timesteps      | 2129920    |
# | train/                  |            |
# |    approx_kl            | 0.04490435 |
# |    clip_fraction        | 0.378      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -29        |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.315     |
# |    n_updates            | 642        |
# |    policy_gradient_loss | -0.0407    |
# |    std                  | 1.34       |
# |    value_loss           | 0.0995     |
# ----------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.12
#   [Jump] step=2,140,000  flight_rate=1.2%  avg_h=0.002m  max_h=0.059m  avg_flight=102.8steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00234     |
# |    flight_rate          | 0.0122      |
# |    max_height           | 0.0589      |
# | time/                   |             |
# |    fps                  | 932         |
# |    iterations           | 131         |
# |    time_elapsed         | 2300        |
# |    total_timesteps      | 2146304     |
# | train/                  |             |
# |    approx_kl            | 0.048457824 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29         |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.298      |
# |    n_updates            | 645         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 1.35        |
# |    value_loss           | 0.108       |
# -----------------------------------------
#   [Jump] step=2,160,000  flight_rate=1.2%  avg_h=0.002m  max_h=0.018m  avg_flight=99.5steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.00183    |
# |    flight_rate          | 0.0121     |
# |    max_height           | 0.0179     |
# | time/                   |            |
# |    fps                  | 933        |
# |    iterations           | 132        |
# |    time_elapsed         | 2317       |
# |    total_timesteps      | 2162688    |
# | train/                  |            |
# |    approx_kl            | 0.04510648 |
# |    clip_fraction        | 0.391      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -29.1      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.32      |
# |    n_updates            | 650        |
# |    policy_gradient_loss | -0.0405    |
# |    std                  | 1.35       |
# |    value_loss           | 0.0926     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 933         |
# |    iterations           | 133         |
# |    time_elapsed         | 2333        |
# |    total_timesteps      | 2179072     |
# | train/                  |             |
# |    approx_kl            | 0.044572312 |
# |    clip_fraction        | 0.38        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.1       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.324      |
# |    n_updates            | 655         |
# |    policy_gradient_loss | -0.0422     |
# |    std                  | 1.35        |
# |    value_loss           | 0.0979      |
# -----------------------------------------
#   [Jump] step=2,180,000  flight_rate=1.2%  avg_h=0.003m  max_h=0.053m  avg_flight=99.7steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00349     |
# |    flight_rate          | 0.0121      |
# |    max_height           | 0.0533      |
# | time/                   |             |
# |    fps                  | 934         |
# |    iterations           | 134         |
# |    time_elapsed         | 2350        |
# |    total_timesteps      | 2195456     |
# | train/                  |             |
# |    approx_kl            | 0.045002107 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.2       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.324      |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.0416     |
# |    std                  | 1.36        |
# |    value_loss           | 0.0994      |
# -----------------------------------------
#   [Jump] step=2,200,000  flight_rate=1.2%  avg_h=0.007m  max_h=0.053m  avg_flight=101.2steps
#   [Health] step=2,200,000  kl=0.04645516723394394  clip=0.38841552734375  expl_var=0.8993515372276306  std=1.3626185655593872
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00671     |
# |    flight_rate          | 0.012       |
# |    max_height           | 0.0527      |
# | time/                   |             |
# |    fps                  | 934         |
# |    iterations           | 135         |
# |    time_elapsed         | 2366        |
# |    total_timesteps      | 2211840     |
# | train/                  |             |
# |    approx_kl            | 0.046455167 |
# |    clip_fraction        | 0.388       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.2       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.325      |
# |    n_updates            | 665         |
# |    policy_gradient_loss | -0.0426     |
# |    std                  | 1.36        |
# |    value_loss           | 0.0943      |
# -----------------------------------------
#   [Jump] step=2,220,000  flight_rate=1.2%  avg_h=0.002m  max_h=0.031m  avg_flight=103.4steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00234     |
# |    flight_rate          | 0.0119      |
# |    max_height           | 0.0307      |
# | time/                   |             |
# |    fps                  | 935         |
# |    iterations           | 136         |
# |    time_elapsed         | 2382        |
# |    total_timesteps      | 2228224     |
# | train/                  |             |
# |    approx_kl            | 0.046010025 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.3       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.333      |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.0418     |
# |    std                  | 1.37        |
# |    value_loss           | 0.0869      |
# -----------------------------------------
#   [Jump] step=2,240,000  flight_rate=1.2%  avg_h=0.002m  max_h=0.054m  avg_flight=100.9steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.00188    |
# |    flight_rate          | 0.0118     |
# |    max_height           | 0.0544     |
# | time/                   |            |
# |    fps                  | 935        |
# |    iterations           | 137        |
# |    time_elapsed         | 2399       |
# |    total_timesteps      | 2244608    |
# | train/                  |            |
# |    approx_kl            | 0.04547141 |
# |    clip_fraction        | 0.382      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -29.3      |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.315     |
# |    n_updates            | 675        |
# |    policy_gradient_loss | -0.0423    |
# |    std                  | 1.37       |
# |    value_loss           | 0.103      |
# ----------------------------------------
#   [Jump] step=2,260,000  flight_rate=1.2%  avg_h=0.008m  max_h=0.069m  avg_flight=113.9steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.00787     |
# |    flight_rate          | 0.0117      |
# |    max_height           | 0.069       |
# | time/                   |             |
# |    fps                  | 936         |
# ...
# |    approx_kl            | 0.040616937 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.9       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.413      |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.0346     |
# |    std                  | 2.18        |
# |    value_loss           | 0.0516      |
# -----------------------------------------
#   [Jump] step=4,780,000  flight_rate=0.7%  avg_h=0.031m  max_h=0.073m  avg_flight=209.2steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.0312     |
# |    flight_rate          | 0.00684    |
# |    max_height           | 0.0735     |
# | time/                   |            |
# |    fps                  | 958        |
# |    iterations           | 292        |
# |    time_elapsed         | 4991       |
# |    total_timesteps      | 4784128    |
# | train/                  |            |
# |    approx_kl            | 0.04103649 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37        |
# |    explained_variance   | 0.869      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.414     |
# |    n_updates            | 1425       |
# |    policy_gradient_loss | -0.0359    |
# |    std                  | 2.19       |
# |    value_loss           | 0.0408     |
# ----------------------------------------
#   [Jump] step=4,800,000  flight_rate=0.7%  avg_h=0.033m  max_h=0.076m  avg_flight=213.6steps
#   [Health] step=4,800,000  kl=0.04473097622394562  clip=0.36455078125  expl_var=0.874152660369873  std=2.1921944618225098
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.0331      |
# |    flight_rate          | 0.00682     |
# |    max_height           | 0.0762      |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 293         |
# |    time_elapsed         | 5008        |
# |    total_timesteps      | 4800512     |
# | train/                  |             |
# |    approx_kl            | 0.044730976 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.4        |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.0376     |
# |    std                  | 2.19        |
# |    value_loss           | 0.0539      |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.10
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 294         |
# |    time_elapsed         | 5024        |
# |    total_timesteps      | 4816896     |
# | train/                  |             |
# |    approx_kl            | 0.035166465 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.1       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.375      |
# |    n_updates            | 1432        |
# |    policy_gradient_loss | -0.00945    |
# |    std                  | 2.2         |
# |    value_loss           | 0.0684      |
# -----------------------------------------
#   [Jump] step=4,820,000  flight_rate=0.7%  avg_h=0.027m  max_h=0.054m  avg_flight=219.0steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.0265      |
# |    flight_rate          | 0.0068      |
# |    max_height           | 0.0537      |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 295         |
# |    time_elapsed         | 5041        |
# |    total_timesteps      | 4833280     |
# | train/                  |             |
# |    approx_kl            | 0.040447578 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.1       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.41       |
# |    n_updates            | 1437        |
# |    policy_gradient_loss | -0.0341     |
# |    std                  | 2.21        |
# |    value_loss           | 0.0428      |
# -----------------------------------------
#   [Jump] step=4,840,000  flight_rate=0.7%  avg_h=0.032m  max_h=0.075m  avg_flight=216.8steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.0322     |
# |    flight_rate          | 0.00679    |
# |    max_height           | 0.0747     |
# | time/                   |            |
# |    fps                  | 958        |
# |    iterations           | 296        |
# |    time_elapsed         | 5058       |
# |    total_timesteps      | 4849664    |
# | train/                  |            |
# |    approx_kl            | 0.04050936 |
# |    clip_fraction        | 0.367      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37.2      |
# |    explained_variance   | 0.814      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.412     |
# |    n_updates            | 1442       |
# |    policy_gradient_loss | -0.0335    |
# |    std                  | 2.22       |
# |    value_loss           | 0.0505     |
# ----------------------------------------
#   [Jump] step=4,860,000  flight_rate=0.7%  avg_h=0.032m  max_h=0.075m  avg_flight=213.2steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.0324      |
# |    flight_rate          | 0.00677     |
# |    max_height           | 0.0753      |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 297         |
# |    time_elapsed         | 5075        |
# |    total_timesteps      | 4866048     |
# | train/                  |             |
# |    approx_kl            | 0.041713953 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.3       |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.405      |
# |    n_updates            | 1447        |
# |    policy_gradient_loss | -0.0317     |
# |    std                  | 2.23        |
# |    value_loss           | 0.0531      |
# -----------------------------------------
#   [Jump] step=4,880,000  flight_rate=0.7%  avg_h=0.035m  max_h=0.078m  avg_flight=217.3steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.0353      |
# |    flight_rate          | 0.00676     |
# |    max_height           | 0.0779      |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 298         |
# |    time_elapsed         | 5092        |
# |    total_timesteps      | 4882432     |
# | train/                  |             |
# |    approx_kl            | 0.041141815 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.3       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.414      |
# |    n_updates            | 1452        |
# |    policy_gradient_loss | -0.0356     |
# |    std                  | 2.23        |
# |    value_loss           | 0.0513      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 299         |
# |    time_elapsed         | 5109        |
# |    total_timesteps      | 4898816     |
# | train/                  |             |
# |    approx_kl            | 0.040690217 |
# |    clip_fraction        | 0.353       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.4       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.43       |
# |    n_updates            | 1457        |
# |    policy_gradient_loss | -0.0392     |
# |    std                  | 2.24        |
# |    value_loss           | 0.0353      |
# -----------------------------------------
#   [Jump] step=4,900,000  flight_rate=0.7%  avg_h=0.038m  max_h=0.075m  avg_flight=218.1steps
#   [Health] step=4,900,000  kl=0.04303114861249924  clip=0.37276611328125  expl_var=0.8800051212310791  std=2.246644973754883
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.0382     |
# |    flight_rate          | 0.00674    |
# |    max_height           | 0.0751     |
# | time/                   |            |
# |    fps                  | 958        |
# |    iterations           | 300        |
# |    time_elapsed         | 5126       |
# |    total_timesteps      | 4915200    |
# | train/                  |            |
# |    approx_kl            | 0.04303115 |
# |    clip_fraction        | 0.373      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37.4      |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.421     |
# |    n_updates            | 1462       |
# |    policy_gradient_loss | -0.0374    |
# |    std                  | 2.25       |
# |    value_loss           | 0.0394     |
# ----------------------------------------
#   [Jump] step=4,920,000  flight_rate=0.7%  avg_h=0.033m  max_h=0.083m  avg_flight=215.5steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.0334     |
# |    flight_rate          | 0.00672    |
# |    max_height           | 0.0828     |
# | time/                   |            |
# |    fps                  | 958        |
# |    iterations           | 301        |
# |    time_elapsed         | 5143       |
# |    total_timesteps      | 4931584    |
# | train/                  |            |
# |    approx_kl            | 0.03943304 |
# |    clip_fraction        | 0.363      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37.5      |
# |    explained_variance   | 0.832      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.407     |
# |    n_updates            | 1467       |
# |    policy_gradient_loss | -0.0328    |
# |    std                  | 2.26       |
# |    value_loss           | 0.0461     |
# ----------------------------------------
#   [Jump] step=4,940,000  flight_rate=0.7%  avg_h=0.034m  max_h=0.060m  avg_flight=215.0steps
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.0336     |
# |    flight_rate          | 0.00671    |
# |    max_height           | 0.0604     |
# | time/                   |            |
# |    fps                  | 958        |
# |    iterations           | 302        |
# |    time_elapsed         | 5160       |
# |    total_timesteps      | 4947968    |
# | train/                  |            |
# |    approx_kl            | 0.04260485 |
# |    clip_fraction        | 0.372      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37.6      |
# |    explained_variance   | 0.842      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.415     |
# |    n_updates            | 1472       |
# |    policy_gradient_loss | -0.0348    |
# |    std                  | 2.26       |
# |    value_loss           | 0.0477     |
# ----------------------------------------
#   [Jump] step=4,960,000  flight_rate=0.7%  avg_h=0.032m  max_h=0.063m  avg_flight=213.8steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.0318      |
# |    flight_rate          | 0.00669     |
# |    max_height           | 0.063       |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 303         |
# |    time_elapsed         | 5178        |
# |    total_timesteps      | 4964352     |
# | train/                  |             |
# |    approx_kl            | 0.041029107 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.6       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.418      |
# |    n_updates            | 1477        |
# |    policy_gradient_loss | -0.0345     |
# |    std                  | 2.27        |
# |    value_loss           | 0.0494      |
# -----------------------------------------
#   [Jump] step=4,980,000  flight_rate=0.7%  avg_h=0.034m  max_h=0.071m  avg_flight=216.0steps
# -----------------------------------------
# | jump/                   |             |
# |    avg_height           | 0.0336      |
# |    flight_rate          | 0.00668     |
# |    max_height           | 0.0711      |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 304         |
# |    time_elapsed         | 5195        |
# |    total_timesteps      | 4980736     |
# | train/                  |             |
# |    approx_kl            | 0.042764015 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.7       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.425      |
# |    n_updates            | 1482        |
# |    policy_gradient_loss | -0.0375     |
# |    std                  | 2.28        |
# |    value_loss           | 0.0314      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 305         |
# |    time_elapsed         | 5212        |
# |    total_timesteps      | 4997120     |
# | train/                  |             |
# |    approx_kl            | 0.042487167 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.7       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.431      |
# |    n_updates            | 1487        |
# |    policy_gradient_loss | -0.0376     |
# |    std                  | 2.29        |
# |    value_loss           | 0.0359      |
# -----------------------------------------
#   [Jump] step=5,000,000  flight_rate=0.7%  avg_h=0.035m  max_h=0.074m  avg_flight=214.5steps
#   [Health] step=5,000,000  kl=0.03958582133054733  clip=0.35870361328125  expl_var=0.833453893661499  std=2.2953262329101562
# ----------------------------------------
# | jump/                   |            |
# |    avg_height           | 0.0351     |
# |    flight_rate          | 0.00667    |
# |    max_height           | 0.074      |
# | time/                   |            |
# |    fps                  | 958        |
# |    iterations           | 306        |
# |    time_elapsed         | 5229       |
# |    total_timesteps      | 5013504    |
# | train/                  |            |
# |    approx_kl            | 0.03958582 |
# |    clip_fraction        | 0.359      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37.8      |
# |    explained_variance   | 0.833      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.403     |
# |    n_updates            | 1492       |
# |    policy_gradient_loss | -0.0318    |
# |    std                  | 2.3        |
# |    value_loss           | 0.0446     |
# ----------------------------------------
#
# --- Training complete ---
# Saved: humanoid_jumper_v2.zip + humanoid_jumper_v2_vecnorm.pkl

# %%
# @title 3. Display Video

from pyvirtualdisplay import Display
import os

display = Display(visible=0, size=(1400, 900))
display.start()
os.environ['MUJOCO_GL'] = 'egl'

import gymnasium as gym
import numpy as np
import imageio
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from IPython.display import Video


def record_jump_video(
    model_path="humanoid_jumper_v2",
    vecnorm_path="humanoid_jumper_v2_vecnorm.pkl",
    video_path="jump_demo_v2.mp4",
    duration=500,
):
    venv = DummyVecEnv([lambda: JumpRewardWrapper(
        gym.make("Humanoid-v5", render_mode="rgb_array"),
        max_episode_steps=duration,
    )])

    if os.path.exists(vecnorm_path):
        env = VecNormalize.load(vecnorm_path, venv)
        env.training = False
        env.norm_reward = False
        print("Loaded VecNormalize stats.")
    else:
        print("Warning: VecNormalize stats not found.")
        env = venv

    if not os.path.exists(model_path + ".zip"):
        print(f"Error: Model {model_path} not found.")
        return None

    model = PPO.load(model_path)
    obs = env.reset()
    frames = []

    print(f"Recording {duration} steps...")
    for _ in range(duration):
        frame = env.venv.envs[0].render()
        frames.append(frame)
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)

    env.close()
    imageio.mimsave(video_path, frames, fps=30)
    print(f"Video saved to {video_path}")
    return video_path


video_file = record_jump_video()

if video_file:
    from IPython.display import display as ipy_display
    ipy_display(Video(video_file, embed=True, html_attributes="controls autoplay loop"))
# Out:
# Loaded VecNormalize stats.
# Recording 500 steps...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Video saved to jump_demo_v2.mp4
# <video controls autoplay loop  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# @title 4. Download Model + Normalizer

from google.colab import files
import os

for f in ["humanoid_jumper_v2.zip", "humanoid_jumper_v2_vecnorm.pkl"]:
    if os.path.exists(f):
        print(f"Downloading {f}...")
        files.download(f)
    else:
        print(f"Not found: {f}")
# Out:
# Downloading humanoid_jumper_v2.zip...
# Downloading humanoid_jumper_v2_vecnorm.pkl...
